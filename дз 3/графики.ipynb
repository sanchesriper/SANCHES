# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
#Задание 1
a = float(input('Введите значение для перемнной a: '))
c = float(input('Введите значение для перемнной c: '))

x_values = np.linspace(-10, 10, 400)

L_values = np.sqrt(np.exp(x_values) - 4 * np.cos(x_values**2 * a**5)) + \
             4 * np.tan(a - x_values**5) / np.e * np.sqrt(np.abs(a + x_values * c**4))
             
data = pd.DataFrame({'x': x_values, 'L': L_values})            

plt.figure(figsize=(10, 6))
sns.lineplot(data=data, x='x', y='L', color='blue')
plt.title('График функции L(x)')
plt.xlabel('x')
plt.ylabel('L')
plt.axhline(0, color='black', linewidth=0.5, ls='--')
plt.axvline(0, color='black', linewidth=0.5, ls='--')
plt.grid()
plt.ylim(-10, 10)
plt.show()
# Out:
# C:\Users\79027\AppData\Local\Temp\ipykernel_9016\1033153842.py:7: RuntimeWarning: invalid value encountered in sqrt
#   L_values = np.sqrt(np.exp(x_values) - 4 * np.cos(x_values**2 * a**5)) + \

# %%
#Задание 2
x_values = np.linspace(-10, 10, 400)

t = 10

L_values = (1 / np.tan(c))**2 + (2 * x_values**2 + 5) / np.sqrt(c + t)

data = pd.DataFrame({'x': x_values, 'L': L_values})

plt.figure(figsize=(10, 6))
sns.lineplot(data=data, x='x', y='L', color='blue')
plt.title('График функции L(x)')
plt.xlabel('x')
plt.ylabel('L')
plt.axhline(0, color='black', linewidth=0.5, linestyle='--')
plt.axvline(0, color='black', linewidth=0.5, linestyle='--')
plt.grid()
plt.ylim(-10, 10)
plt.legend(['L'])
plt.show()

# %%
#Задание 3
a = float(input('Введите значение для перемнной a: '))
c = float(input('Введите значение для перемнной c: '))
y = float(input('Введите значение для перемнной y: '))
h = float(input('Введите значение для перемнной h: '))

x_values = np.linspace(-10, 10, 400)

L_values = np.sqrt(np.exp(x_values) - 4 * np.cos(x_values * a)) + \
                4 * np.tan(a - x_values) / np.e * np.sqrt(np.abs(a + x_values * c))

data_L = pd.DataFrame({'x': x_values, 'L': L_values})

A_values_arr = np.full_like(x_values, A_values)

A_values = np.tan(y**3 - h**4) + (h**2) / (np.sin(h)**3) + y


plt.figure(figsize=(10, 6))
sns.lineplot(data=data_L, x='x', y='L', color='blue', label='L(x)')
plt.title('Графики функций L(x) и A(y, h)')
plt.xlabel('x')
plt.ylabel('L')
plt.axhline(0, color='black', linewidth=0.5, linestyle='--')
plt.axvline(0, color='black', linewidth=0.5, linestyle='--')
plt.grid()
plt.legend()
plt.ylim(-10, 10)
plt.show()
# Out:
# C:\Users\79027\AppData\Local\Temp\ipykernel_9016\2462242045.py:9: RuntimeWarning: invalid value encountered in sqrt
#   L_values = np.sqrt(np.exp(x_values) - 4 * np.cos(x_values * a)) + \

# %%
#Задание 4
y_values = np.linspace(-10, 10, 400)

F_values = np.sqrt((2 + y_values)**2 + 7 * np.sqrt(np.abs(np.sin(y_values + 5))))

data_F = pd.DataFrame({'y': y_values, 'F': F_values})

plt.figure(figsize=(10, 6))
sns.lineplot(data=data_F, x='y', y='F', color='blue', label='F(y)')
plt.title('График функции F(y)')
plt.xlabel('y')
plt.ylabel('F')
plt.axhline(0, color='black', linewidth=0.5, linestyle='--')
plt.axvline(0, color='black', linewidth=0.5, linestyle='--')
plt.grid()
plt.legend()
plt.ylim(0, 10)
plt.show()

# %%
#Задание 5
y = float(input('Введите значение для перемнной y: '))
z = float(input('Введите значение для перемнной z: '))

x_values = np.linspace(-10, 10, 400)

G_values = np.tan(x_values**4 - 6) - (np.cos(z + x_values * y)**3) / (np.cos(x_values**3)**4 * (y**2))

data = pd.DataFrame({'x': x_values, 'G': G_values})

plt.figure(figsize=(10, 6))
sns.lineplot(data=data, x='x', y='G', color='blue')
plt.title('График функции G(x)')
plt.xlabel('x')
plt.ylabel('G')
plt.axhline(0, color='black', linewidth=0.5, linestyle='--')
plt.axvline(0, color='black', linewidth=0.5, linestyle='--')
plt.grid()
plt.legend(['G(x)'])
plt.ylim(-10, 10)
plt.show()

# %%
#Задание 6
b = 10
K_values = np.sqrt(x_values + b - a) + np.log(np.abs(x_values) + 1) / np.arctan(b + a)

data_k = pd.DataFrame({'x': x_values, 'K': K_values})

plt.figure(figsize=(10, 6))
sns.lineplot(data=data_k, x='x', y='K', color='blue')
plt.title('График функции K(x)')
plt.xlabel('x')
plt.ylabel('K')
plt.axhline(0, color='black', linewidth=0.5, linestyle='--')
plt.axvline(0, color='black', linewidth=0.5, linestyle='--')
plt.grid()
plt.ylim(-10, 10)
plt.show()
# Out:
# C:\Users\79027\AppData\Local\Temp\ipykernel_9016\4132513056.py:3: RuntimeWarning: invalid value encountered in sqrt
#   K_values = np.sqrt(x_values + b - a) + np.log(np.abs(x_values) + 1) / np.arctan(b + a)

# %%
#Задание 7
D_values = np.cos(x_values**3 + 6) - np.sin(a - x_values) / (np.log(x_values**4 + 1) - 2 * (np.sin(x_values))**5)

data_d = pd.DataFrame({'x': x_values, 'D': D_values})

plt.figure(figsize=(10, 6))
sns.lineplot(data=data_d, x='x', y='D', color='blue')
plt.title('График функции D(x)')
plt.xlabel('x')
plt.ylabel('D')
plt.axhline(0, color='black', linewidth=0.5, linestyle='--')
plt.axvline(0, color='black', linewidth=0.5, linestyle='--')
plt.grid()
plt.legend()
plt.ylim(-10, 10)
plt.show()
# Out:
# C:\Users\79027\AppData\Local\Temp\ipykernel_9016\5037227.py:14: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
#Задание 8
P_values = (a**5 + (np.sin(y_values[:, np.newaxis] - c)**4)) / \
           (np.sin(x_values[:, np.newaxis] + y_values)**3 + np.abs(x_values[:, np.newaxis] - y_values))

P_avg = np.mean(P_values, axis=1)

data_p = pd.DataFrame({'x': x_values, 'P': P_avg})

plt.figure(figsize=(10, 6))
sns.lineplot(data=data_p, x='x', y='P', color='blue')
plt.title('График функции P(x)')
plt.xlabel('x')
plt.ylabel('P')
plt.axhline(0, color='black', linewidth=0.5, linestyle='--')
plt.axvline(0, color='black', linewidth=0.5, linestyle='--')
plt.grid()
plt.ylim(-10, 10)
plt.show()

# %%
#Задание 9
d = 10
R_values = (np.cos(y_values[:, np.newaxis])**3 + 2**x_values[:, np.newaxis] * d) / \
           (np.exp(y_values[:, np.newaxis]) + np.log(np.sin(x_values[:, np.newaxis])**2 + 7.4))

R_avg = np.mean(R_values, axis=1)

data_r = pd.DataFrame({'x': x_values, 'R': R_avg})

plt.figure(figsize=(10, 6))
sns.lineplot(data=data_r, x='x', y='R', color='blue')
plt.title('График функции R(x)')
plt.xlabel('x')
plt.ylabel('R')
plt.axhline(0, color='black', linewidth=0.5, linestyle='--')
plt.axvline(0, color='black', linewidth=0.5, linestyle='--')
plt.grid()
plt.ylim(-10, 10)
plt.show()

# %%
#Задание 10
U_values = np.exp(x_values**3) + (np.cos(x_values - 4)**2 / (np.arctan(x_values) + 5.2 * a))

data_U = pd.DataFrame({'x': x_values, 'U': U_values})

plt.figure(figsize=(10, 6))
sns.lineplot(data=data_U, x='x', y='U', color='blue', label='U(x)')
plt.title('График функции U(x)')
plt.xlabel('x')
plt.ylabel('U')
plt.axhline(0, color='black', linewidth=0.5, linestyle='--')
plt.axvline(0, color='black', linewidth=0.5, linestyle='--')
plt.grid()
plt.ylim(-10, 10)
plt.show()
# Out:
# C:\Users\79027\AppData\Local\Temp\ipykernel_9016\2852016535.py:2: RuntimeWarning: overflow encountered in exp
#   U_values = np.exp(x_values**3) + (np.cos(x_values - 4)**2 / (np.arctan(x_values) + 5.2 * a))

# %%
#Задание 11
I_values = (2.33 * np.log(np.sqrt(1 + np.cos(y_values)**2))) / (np.exp(y_values) + np.sin(x_values)**2)

data = pd.DataFrame({'y': y_values, 'I': I_values})

plt.figure(figsize=(10, 6))
sns.lineplot(data=data, x='y', y='I', color='blue')
plt.title('График функции I(y)')
plt.xlabel('y')
plt.ylabel('I')
plt.axhline(0, color='black', linewidth=0.5, linestyle='--')
plt.axvline(0, color='black', linewidth=0.5, linestyle='--')
plt.grid()
plt.ylim(-10, 10)
plt.show()

# %%
#Задание 12
a = float(input('Введите значение для перемнной a: '))
c = float(input('Введите значение для перемнной c: '))

x_values = np.linspace(-10, 10, 400)

y = np.linspace(-10, 10, 400)

G_values = (np.cos(x_values)**3 * np.abs(y + x_values) - 
            (x_values + y) / (np.arctan((x_values + a)**4) * (x_values**5 + 1e-10)))

data = pd.DataFrame({'x': x_values, 'G': G_values})

plt.figure(figsize=(10, 6))
sns.lineplot(data=data, x='x', y='G', color='blue')
plt.title('График функции G(x)')
plt.xlabel('x')
plt.ylabel('G')
plt.axhline(0, color='black', linewidth=0.5, linestyle='--')
plt.axvline(0, color='black', linewidth=0.5, linestyle='--')
plt.grid()
plt.legend(['G(x)'])
plt.ylim(-10, 10) 
plt.show()
# Out:
# C:\Users\79027\AppData\Local\Temp\ipykernel_9016\485838018.py:10: RuntimeWarning: divide by zero encountered in divide
#   (x_values + y) / (np.arctan((x_values + a)**4) * (x_values**5 + 1e-10)))

# %%
#Задание 13
a = float(input('Введите значение для перемнной a: '))
b = float(input('Введите значение для перемнной b: '))

x_values = np.linspace(-10, 10, 400)

R_values = (a / x_values) - a + (b ** x_values) + (np.cos(x_values) ** 3) / (np.log(a) ** 3) + 4.5

data = pd.DataFrame({'x': x_values, 'R': R_values})

plt.figure(figsize=(10, 6))
sns.lineplot(data=data, x='x', y='R', color='blue')
plt.title('График функции R(x)')
plt.xlabel('x')
plt.ylabel('R')
plt.axhline(0, color='black', linewidth=0.5, linestyle='--')
plt.axvline(0, color='black', linewidth=0.5, linestyle='--')
plt.grid()
plt.ylim(-10, 10)
plt.xlim(-10, 10)
plt.show()

# %%
#Задание 14
x_values = np.linspace(-10, 10, 400)

R_values = np.sin(x_values**2 + 4)**3 + 4.3 / np.sin(x_values**4)**3

data = pd.DataFrame({'x': x_values, 'R': R_values})

plt.figure(figsize=(10, 6))
sns.lineplot(data=data, x='x', y='R', color='blue')
plt.title('График функции R(x)')
plt.xlabel('x')
plt.ylabel('R')
plt.axhline(0, color='black', linewidth=0.5, linestyle='--')
plt.axvline(0, color='black', linewidth=0.5, linestyle='--')
plt.grid()
plt.ylim(-10, 10)
plt.show()

# %%
#Задание 15
m = float(input('Введите значение для переменной m: '))
y = float(input('Введите значение для переменной y: '))

m_values = np.linspace(-10, 10, 400)

N_values = (m_values**2 + 2.8*m_values + 0.355) / (np.cos(np.radians(2*y)) + 3.6)

data = pd.DataFrame({'m': m_values, 'N': N_values})

plt.figure(figsize=(10, 6))
sns.lineplot(data=data, x='m', y='N', color='blue')
plt.title('График функции N(m, y)')
plt.xlabel('m')
plt.ylabel('N')
plt.axhline(0, color='black', linewidth=0.5, linestyle='--')
plt.axvline(0, color='black', linewidth=0.5, linestyle='--')
plt.grid()
plt.ylim(-10, 10)
plt.show()

# %%
#Задание 16
a = float(input('Введите значение для перемнной a: '))
c = float(input('Введите значение для перемнной c: '))

x_values = np.linspace(-10, 10, 400)

P_values = np.sin(x_values)**3 + np.log(2 * y + 3 * x_values) / (t * np.e) + np.sqrt(np.abs(x_values))

data = pd.DataFrame({'x': x_values,'P': P_values})

plt.figure(figsize=(10, 6))
plt.plot(x_values, P_values, label='P(x)', color='blue')
plt.title('График функции P(x) с использованием Seaborn')
plt.xlabel('x')
plt.ylabel('P')
plt.axhline(0, color='black', linewidth=0.5, linestyle='--')
plt.axvline(0, color='black', linewidth=0.5, linestyle='--')
plt.grid()
plt.legend()
plt.ylim(-10, 10)
plt.show()
# Out:
# C:\Users\79027\AppData\Local\Temp\ipykernel_9016\1746384856.py:7: RuntimeWarning: invalid value encountered in log
#   P_values = np.sin(x_values)**3 + np.log(2 * y + 3 * x_values) / (t * np.e) + np.sqrt(np.abs(x_values))

# %%
#Задание 17
a = float(input('Введите значение для перемнной a: '))
b = float(input('Введите значение для перемнной b: '))
c = float(input('Введите значение для перемнной c: '))
y = float(input('Введите значение для перемнной y: '))

x_values = np.linspace(-10, 10, 400)

T_values = np.sqrt(x_values + b - a) + np.log(y) / np.arctan(b + a)

data = pd.DataFrame({'x': x_values,'T': T_values})

plt.figure(figsize=(10, 6))
plt.plot(x_values, T_values, label='T(x)', color='blue')
plt.title('График функции T(x) с использованием Seaborn')
plt.xlabel('x')
plt.ylabel('T')
plt.axhline(0, color='black', linewidth=0.5, linestyle='--')
plt.axvline(0, color='black', linewidth=0.5, linestyle='--')
plt.grid()
plt.legend()
plt.ylim(-10, 10)
plt.show()
# Out:
# C:\Users\79027\AppData\Local\Temp\ipykernel_9016\3334979108.py:9: RuntimeWarning: invalid value encountered in sqrt
#   T_values = np.sqrt(x_values + b - a) + np.log(y) / np.arctan(b + a)

# %%
#Задание 18
y_values = np.linspace(-10, 10, 400) 
t = float(input("Введите значение для перемнной t: "))

S_values = 4.351 * np.power(y_values, 3) + (2 * t * np.log(np.abs(t))) / np.sqrt(np.cos(2 * y_values)) + 4.351

data_S = pd.DataFrame({'y': y_values, 'S': S_values})

plt.figure(figsize=(10, 6))
sns.lineplot(data=data_S, x='y', y='S', color='blue')
plt.title('График функции S(y)')
plt.xlabel('y')
plt.ylabel('S')
plt.axhline(0, color='black', linewidth=0.5, linestyle='--')
plt.axvline(0, color='black', linewidth=0.5, linestyle='--')
plt.grid()
plt.ylim(-10, 10)
plt.show()
# Out:
# C:\Users\79027\AppData\Local\Temp\ipykernel_9016\2970867538.py:5: RuntimeWarning: invalid value encountered in sqrt
#   S_values = 4.351 * np.power(y_values, 3) + (2 * t * np.log(np.abs(t))) / np.sqrt(np.cos(2 * y_values)) + 4.351

# %%
#Задание 19
a = float(input('Введите значение для перемнной a: '))
b = float(input('Введите значение для перемнной b: '))
c = float(input('Введите значение для перемнной c: '))
y = float(input('Введите значение для перемнной y: '))

x_values = np.linspace(-10, 10, 400)

L_values = np.sqrt(np.exp(x_values) - 4 * np.cos(x_values ** 2 * a * 5)) + \
               4 * np.tan(a - x_values ** 5) / np.e * np.sqrt(np.abs(a + x_values * c ** 4))

data_L = pd.DataFrame({'x': x_values, 'L': L_values})

D_values = (np.power(c, -a) - np.sqrt(6) - np.cos(3 * a * b)) / np.power(np.sin(a * np.arcsin(x_values) + np.log(y)), 2)

data_D = pd.DataFrame({'x': x_values, 'D': D_values})

plt.figure(figsize=(10, 12))
plt.subplot(2, 1, 1)
sns.lineplot(data=data_L, x='x', y='L', color='blue')
plt.title('График функции L(x)')
plt.xlabel('x')
plt.ylabel('L')
plt.axhline(0, color='black', linewidth=0.5, linestyle='--')
plt.axvline(0, color='black', linewidth=0.5, linestyle='--')
plt.grid()
plt.ylim(-10, 10)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\79027\AppData\Local\Temp\ipykernel_9016\3524216240.py:9: RuntimeWarning: invalid value encountered in sqrt
#   L_values = np.sqrt(np.exp(x_values) - 4 * np.cos(x_values ** 2 * a * 5)) + \
# C:\Users\79027\AppData\Local\Temp\ipykernel_9016\3524216240.py:14: RuntimeWarning: invalid value encountered in arcsin
#   D_values = (np.power(c, -a) - np.sqrt(6) - np.cos(3 * a * b)) / np.power(np.sin(a * np.arcsin(x_values) + np.log(y)), 2)

# %%
#Задание 20
a = float(input('Введите значение для перемнной a: '))
b = float(input('Введите значение для перемнной b: '))
c = float(input('Введите значение для перемнной c: '))
y = float(input('Введите значение для перемнной y: '))

x_values = np.linspace(-10, 10, 400)

U_values = np.tan(y)**3 + np.sin(x_values)**5 + np.sqrt(b - c) / (np.sqrt(a - b + c))

data = pd.DataFrame({'x': x_values,'U': U_values})

plt.figure(figsize=(10, 6))
plt.plot(x_values, U_values, label='U(x)', color='blue')
plt.title('График функции U(x) с использованием Seaborn')
plt.xlabel('x')
plt.ylabel('U')
plt.axhline(0, color='black', linewidth=0.5, linestyle='--')
plt.axvline(0, color='black', linewidth=0.5, linestyle='--')
plt.grid()
plt.legend()
plt.ylim(-10, 10)
plt.show()

# %%
#Задание 21
a = float(input('Введите значение для перемнной a: '))
z = float(input('Введите значение для перемнной z: '))

x_values = np.linspace(-10, 10, 400)

N_values = 5 * np.sqrt((z + np.sqrt(z * x_values)) / np.exp(x_values)) + a**5 * np.arctan(x_values)

plt.figure(figsize=(10, 6))
plt.plot(x_values, N_values, label='N(x)', color='blue')
plt.title('График функции N(x)')
plt.xlabel('x')
plt.ylabel('N')
plt.axhline(0, color='black', linewidth=0.5, linestyle='--')
plt.axvline(0, color='black', linewidth=0.5, linestyle='--')
plt.grid()
plt.legend()
plt.ylim(-10, 10)
plt.show()
# Out:
# C:\Users\79027\AppData\Local\Temp\ipykernel_9016\490038231.py:7: RuntimeWarning: invalid value encountered in sqrt
#   N_values = 5 * np.sqrt((z + np.sqrt(z * x_values)) / np.exp(x_values)) + a**5 * np.arctan(x_values)

# %%
#Задание 22
a = float(input('Введите значение для перемнной a: '))
y = float(input('Введите значение для перемнной y: '))

x_values = np.linspace(-10, 10, 400)

F_values = np.cos(x_values**2 + 2) + 3.5 * x_values**2 + 1 / np.cos(y)**2

data = pd.DataFrame({'x': x_values,'F': F_values})

plt.figure(figsize=(10, 6))
plt.plot(x_values, F_values, label='F(x)', color='blue')
plt.title('График функции F(x) с использованием Seaborn')
plt.xlabel('x')
plt.ylabel('F')
plt.axhline(0, color='black', linewidth=0.5, linestyle='--')
plt.axvline(0, color='black', linewidth=0.5, linestyle='--')
plt.grid()
plt.legend()
plt.ylim(-10, 10)
plt.show()

# %%
#Задание 23
a = float(input('Введите значение для перемнной a: '))
b = float(input('Введите значение для перемнной b: '))
z = float(input('Введите значение для перемнной z: '))

x_values = np.linspace(0.1, 10, 400)

F_values = np.sqrt(np.abs(x_values) + np.cos(x_values)**2 + z**4) / np.log(x_values) - np.arcsin(b * x_values - a)

data = pd.DataFrame({'x': x_values,'F': F_values})

plt.figure(figsize=(10, 6))
plt.plot(x_values, F_values, label='F(x)', color='blue')
plt.title('График функции F(x) с использованием Seaborn')
plt.xlabel('x')
plt.ylabel('F')
plt.axhline(0, color='black', linewidth=0.5, linestyle='--')
plt.axvline(0, color='black', linewidth=0.5, linestyle='--')
plt.grid()
plt.legend()
plt.ylim(-10, 10)
plt.show()
# Out:
# C:\Users\79027\AppData\Local\Temp\ipykernel_9016\2029315202.py:8: RuntimeWarning: invalid value encountered in arcsin
#   F_values = np.sqrt(np.abs(x_values) + np.cos(x_values)**2 + z**4) / np.log(x_values) - np.arcsin(b * x_values - a)

# %%
#Задание 24
a = float(input('Введите значение для перемнной a: '))
b = float(input('Введите значение для перемнной b: '))
c = float(input('Введите значение для перемнной c: '))
z = float(input('Введите значение для перемнной z: '))

# Генерация значений x
x_values = np.linspace(-10, 10, 400)

# Расчет значений f
f_values = np.cos(b * x_values**5)**7 - np.sin(a**2) + \
           np.cos(x_values**3 + z**5 - a**2) / np.arcsin(a**2) + \
           np.arccos(x_values**7 - a**2)

# Создание DataFrame для значений L и f
data = pd.DataFrame({'x': x_values, 'L': L_values, 'f': f_values})

# Построение графиков
plt.figure(figsize=(10, 6))
plt.subplot(2, 1, 2)
sns.lineplot(data=data, x='x', y='f', color='blue')
plt.title('График функции f(x)')
plt.xlabel('x')
plt.ylabel('f')
plt.axhline(0, color='black', linewidth=0.5, linestyle='--')
plt.axvline(0, color='black', linewidth=0.5, linestyle='--')
plt.grid()
plt.ylim(-10, 10)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\79027\AppData\Local\Temp\ipykernel_9016\4144455824.py:13: RuntimeWarning: invalid value encountered in arccos
#   np.arccos(x_values**7 - a**2)

# %%
#Задание 25
a = float(input('Введите значение для перемнной a: '))
y = float(input('Введите значение для перемнной y: '))

x_values = np.linspace(-2, 2, 400)

J_values = (1/np.tan(a)**3 + np.arctan(a)**2) / np.sqrt(y**(np.tan(x_values)))

plt.figure(figsize=(10, 6))
plt.plot(x_values, J_values, label='J(x)', color='blue')
plt.title('График функции J(x)')
plt.xlabel('x')
plt.ylabel('J')
plt.axhline(0, color='black', linewidth=0.5, linestyle='--')
plt.axvline(0, color='black', linewidth=0.5, linestyle='--')
plt.grid()
plt.legend()
plt.ylim(-10, 10)
plt.show()
# Out:
# C:\Users\79027\AppData\Local\Temp\ipykernel_9016\2691245727.py:7: RuntimeWarning: overflow encountered in power
#   J_values = (1/np.tan(a)**3 + np.arctan(a)**2) / np.sqrt(y**(np.tan(x_values)))
# C:\Users\79027\AppData\Local\Temp\ipykernel_9016\2691245727.py:7: RuntimeWarning: divide by zero encountered in divide
#   J_values = (1/np.tan(a)**3 + np.arctan(a)**2) / np.sqrt(y**(np.tan(x_values)))

# %%
#Задание 26
y = float(input('Введите значение для перемнной y: '))
k = float(input('Введите значение для перемнной k: '))

x_values = np.linspace(0, 10, 400)

U_values = np.log(x_values**3 + y) - (y**4 / np.exp(y)) + 5.4 * k**3

data = pd.DataFrame({'x': x_values,'U': U_values})

plt.figure(figsize=(10, 6))
plt.plot(x_values, U_values, label='U(x)', color='blue')
plt.title('График функции U(x) с использованием Seaborn')
plt.xlabel('x')
plt.ylabel('U')
plt.axhline(0, color='black', linewidth=0.5, linestyle='--')
plt.axvline(0, color='black', linewidth=0.5, linestyle='--')
plt.grid()
plt.legend()
plt.ylim(-10, 10)
plt.show()

# %%
#Задание 27
a = float(input('Введите значение для перемнной a: '))
y = float(input('Введите значение для перемнной y: '))
c = float(input('Введите значение для перемнной c: '))

x_values = np.linspace(-10, 10, 400)

P_values = (a**5 + np.arccos(a + x_values**3) - np.sin(y - c)**4) / (np.sin(x_values + y)**3 ) + np.abs(x_values - y)

plt.figure(figsize=(10, 6))
plt.plot(x_values, P_values, label='P(x)', color='blue')
plt.title('График функции P(x)')
plt.xlabel('x')
plt.ylabel('P')
plt.axhline(0, color='black', linewidth=0.5, linestyle='--')
plt.axvline(0, color='black', linewidth=0.5, linestyle='--')
plt.grid()
plt.legend()
plt.ylim(-10, 10)
plt.show()
# Out:
# C:\Users\79027\AppData\Local\Temp\ipykernel_9016\2437881627.py:8: RuntimeWarning: invalid value encountered in arccos
#   P_values = (a**5 + np.arccos(a + x_values**3) - np.sin(y - c)**4) / (np.sin(x_values + y)**3 ) + np.abs(x_values - y)

# %%
#Задание 28
c = float(input('Введите значение для перемнной c: '))
y = float(input('Введите значение для перемнной y: '))

x_values = np.linspace(-10, 10, 400)

G_values = np.tan(x_values**4 - 6) - (np.cos(3 * x_values) * (x_values + x_values**3 * y)) / (np.cos(x_values**3)**2 * c**2 + 1e-10)

data = pd.DataFrame({'x': x_values,'G': G_values})

plt.figure(figsize=(10, 6))
plt.plot(x_values, G_values, label='G(x)', color='blue')
plt.title('График функции G(x) с использованием Seaborn')
plt.xlabel('x')
plt.ylabel('G')
plt.axhline(0, color='black', linewidth=0.5, linestyle='--')
plt.axvline(0, color='black', linewidth=0.5, linestyle='--')
plt.grid()
plt.legend()
plt.ylim(-10, 10)
plt.show()

# %%
#Задание 29
a = float(input('Введите значение для перемнной a: '))
c = float(input('Введите значение для перемнной c: '))
d = float(input('Введите значение для перемнной d: '))

x_values = np.linspace(-10, 10, 400)
y_values = np.linspace(-10, 10, 400)

R_values = np.cos(y_values)**2 + (2.4 * d) / np.exp(y_values) + np.log(np.sin(x_values)**2 + 6)

data = pd.DataFrame({'x': x_values, 'R': R_values[:len(x_values)]}) 

plt.figure(figsize=(10, 6))
sns.lineplot(data=data, x='x', y='R', color='blue')
plt.title('График функции R(x)')
plt.xlabel('x')
plt.ylabel('R')
plt.axhline(0, color='black', linewidth=0.5, linestyle='--')
plt.axvline(0, color='black', linewidth=0.5, linestyle='--')
plt.grid()
plt.ylim(-10, 10)
plt.show()

# %%
#Задание 30
x_input = float(input('Введите значение для перемнной x: '))

x_values = np.linspace(-10, 10, 400)

K_values = np.sqrt((3 + x_values)**6) - np.log(x_values) + np.sin(6 * x_values**2)

data = pd.DataFrame({'x': x_values,'K': K_values})

plt.figure(figsize=(10, 6))
sns.lineplot(data=data, x='x', y='K', color='blue')
plt.title('График функции K(x)')
plt.xlabel('x')
plt.ylabel('K')
plt.axhline(0, color='black', linewidth=0.5, linestyle='--')
plt.axvline(0, color='black', linewidth=0.5, linestyle='--')
plt.grid()
plt.ylim(-10, 10)
plt.show()
# Out:
# C:\Users\79027\AppData\Local\Temp\ipykernel_9016\2185653.py:6: RuntimeWarning: invalid value encountered in log
#   K_values = np.sqrt((3 + x_values)**6) - np.log(x_values) + np.sin(6 * x_values**2)
