# %%
import numpy as np
import matplotlib.pyplot as plt
import math

# %%
#Задание 1
A = True
B = False
C = False


result_a = (A or (not A and B)) or C
result_b = (not A) or (A and (B or C))
result_c = (A or (B and not C)) and C

print("Результат a:", result_a)
print("Результат b:", result_b)
print("Результат c:", result_c)

# %%
class LogicalExpressions:
    def __init__(self, A, B, C):
        self.A = A
        self.B = B
        self.C = C

    def expression_a(self):
        return (self.A or (not self.A and self.B)) or self.C

    def expression_b(self):
        return (not self.A) or (self.A and (self.B or self.C))

    def expression_c(self):
        return (self.A or (self.B and not self.C)) and self.C


A = True  
B = False 
C = False

logical_expressions = LogicalExpressions(A, B, C)

print("Результат a:", logical_expressions.expression_a())
print("Результат b:", logical_expressions.expression_b())
print("Результат в:", logical_expressions.expression_c())

# %%
#Задание 2
X = False
Y = True
Z = False

result_x = X and not (Z or Y) or not Z
result_y = not X or X and (Y or Z)
result_z = (X or Y and not Z) and Z

print("Результат x:", result_x)
print("Результат y:", result_y)
print("Результат z:", result_z)

# %%
class LogicalExpressions:
    def __init__(self, X, Y, Z):
        self.X = X
        self.Y = Y
        self.Z = Z

    def expression_x(self):
        return self.X and not (self.Z or self.Y) or not self.Z

    def expression_y(self):
        return not self.X or self.X and (self.Y or self.Z)

    def expression_z(self):
        return (self.X or self.Y and not self.Z) and self.Z


X = False
Y = True
Z = False

logical_expressions = LogicalExpressions(X, Y, Z)

print("Результат x:", logical_expressions.expression_x())
print("Результат y:", logical_expressions.expression_y())
print("Результат z:", logical_expressions.expression_z())

# %%
#Задание 3
x = 2
y = 1

result_a = (not (x * y < 0)) and (y > x)

x = 2
y = -2

result_b = (x >= 2) or (y**2 != 5)

print("Результат a:", result_a)
print("Результат b:", result_b)

# %%
class LogicalExpressions:
    def __init__(self, x, y):
        self.x = x
        self.y = y

    def expression_a(self):
        return (not (self.x * self.y < 0)) and (self.y > self.x)

    def expression_b(self):
        return (self.x >= 2) or (self.y**2 != 5)

x_a = 2
y_a = 1

logical_expressions_a = LogicalExpressions(x_a, y_a)
result_a = logical_expressions_a.expression_a()
print("Результат a:", result_a)

x_b = 2
y_b = -2

logical_expressions_b = LogicalExpressions(x_b, y_b)
result_b = logical_expressions_b.expression_b()
print("Результат b:", result_b)

# %%
#Задание 4
A % 2 == 0 or A % 3 == 0

# %%
class LogicalExpressions:
    def __init__(self, A):
        self.A = A


    def expression_a(self):
        return self.A % 2 == 0 or self.A % 3 == 0


A = 5

logical_expressions = LogicalExpressions(A)

print(logical_expressions.expression_a())

# %%
#Задание 5
A % 3 == 0 or B % 5 == 0

# %%
class LogicalExpressions:
    def __init__(self, A, B):
        self.A = A
        self.B = B

    def expression_a(self):
        return self.A % 3 == 0 or self.B % 5 == 0


A = 6

logical_expressions = LogicalExpressions(A, B)

print(logical_expressions.expression_a())

# %%
#Задание 6 
x = False
y = False
z = True

result_x = x or y and not z 
result_y = not x and not y  
result_z = not (x and z) or y 

print("Результат x:", result_x)
print("Результат y:", result_y)
print("Результат z:", result_z)

# %%
class LogicalExpressions:
    def __init__(self, x, y, z):
        self.x= x
        self.y = y
        self.z = z

    def expression_x(self):
        return self.x or self.y and not self.z 

    def expression_y(self):
        return not self.x and not self.y  

    def expression_z(self):
        return not (self.x and self.z) or self.y 


x = False
y = False
z = True

logical_expressions = LogicalExpressions(x, y, z)

print("Результат x:", logical_expressions.expression_x())
print("Результат y:", logical_expressions.expression_y())
print("Результат z:", logical_expressions.expression_z())

# %%
#Задание 7 
result_a = y = 2 * math.tan(x)
result_b = y = 3 / (x - 1)

print("Результат a:", result_a)
print("Результат b:", result_b)

# %%
class LogicalExpressions:
    def __init__(self, x, y):
        self.x = x
        self.y = y

    def expression_a(self):
        return 2 * math.tan(x)
    
    def expression_b(self):
        return 3 / (x - 1)

logical_expressions = LogicalExpressions(x, y)

print("Результат a:", result_a)
print("Результат b:", result_b)

# %%
#Задание 8 
x = 1
y = 2

result_a = (x >= 0) and (y**2 != 4)

x = 2
y = 1

result_b = (x * y != 0) or (y > x)

print("Результат a:", result_a)
print("Результат b:", result_b)

# %%
class LogicalExpressions:
    def __init__(self, x, y):
        self.x = x
        self.y = y

    def expression_a(self):
        return (x >= 0) and (y**2 != 4)

    def expression_b(self):
        return (x * y != 0) or (y > x)

x_a = 1
y_a = 2

logical_expressions_a = LogicalExpressions(x_a, y_a)
result_a = logical_expressions_a.expression_a()
print("Результат a:", result_a)

x_b = 2
y_b = 1

logical_expressions_b = LogicalExpressions(x_b, y_b)
result_b = logical_expressions_b.expression_b()
print("Результат b:", result_b)

# %%
#Задание 9 
x = 1
y = 2

result_a = (not (x * y < 0)) or (y > x)

x = 2
y = 1

result_b = (x * y != 0) and (y < x)

print("Результат a:", result_a)
print("Результат b:", result_b)

# %%
class LogicalExpressions:
    def __init__(self, x, y):
        self.x = x
        self.y = y

    def expression_a(self):
        return (not (x * y < 0)) or (y > x)

    def expression_b(self):
        return (x * y != 0) and (y < x)

x_a = 1
y_a = 2

logical_expressions_a = LogicalExpressions(x_a, y_a)
result_a = logical_expressions_a.expression_a()
print("Результат a:", result_a)

x_b = 2
y_b = 1

logical_expressions_b = LogicalExpressions(x_b, y_b)
result_b = logical_expressions_b.expression_b()
print("Результат b:", result_b)

# %%
#Задание 10 
a = True
b = False
c = True

result_a = a or not ( a and b) or c
result_b = not a or c and not ( b or c)
result_c = ( a or b and not c) or a 

print("Результат a:", result_a)
print("Результат b:", result_b)
print("Результат c:", result_c)

# %%
class LogicalExpressions:
    def __init__(self, a, b, c):
        self.a = a
        self.b = b
        self.c = c

    def expression_a(self):
        return self.a or not ( self.a and self.b) or self.c

    def expression_b(self):
        return not self.a or self.c and not ( self.b or self.c)

    def expression_c(self):
        return ( self.a or self.b and not self.c) or self.a 


a = True  
b = False 
c = True

logical_expressions = LogicalExpressions(a, b, c)

print("Результат a:", logical_expressions.expression_a())
print("Результат b:", logical_expressions.expression_b())
print("Результат в:", logical_expressions.expression_c())
